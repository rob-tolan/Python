# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10, 4),
   index = pd.date_range('1/1/2000', periods=10),
   columns = ['A', 'B', 'C', 'D'])

print(df)
r = df.rolling(window=3,min_periods=1)
print(r)
# Out:
#                    A         B         C         D
# 2000-01-01 -0.959501  1.199325 -0.299174  0.939967
# 2000-01-02 -0.584426 -0.759166 -0.637235 -1.469191
# 2000-01-03  0.256041  0.177726 -0.265617 -2.106407
# 2000-01-04  1.061597  0.629926 -2.127822 -1.464975
# 2000-01-05  0.214481 -1.180430 -1.319292 -2.138558
# 2000-01-06 -0.042008 -1.077194  0.717692 -0.162573
# 2000-01-07 -1.805380  0.549944 -0.064636 -0.148459
# 2000-01-08  0.314507  1.132512  1.617805 -1.123857
# 2000-01-09  0.565891 -0.175696  0.936185 -0.149996
# 2000-01-10  1.575126 -0.116992 -0.177115  0.557306
# Rolling [window=3,min_periods=1,center=False,axis=0]

# %%
df = pd.DataFrame(np.random.randn(10, 4),
   index = pd.date_range('1/1/2000', periods=10),
   columns = ['A', 'B', 'C', 'D'])
print(df)
r = df.rolling(window=3,min_periods=1)
print(r.aggregate(np.sum))
# Out:
#                    A         B         C         D
# 2000-01-01  0.424351  1.592704  1.524568  0.444328
# 2000-01-02  0.212473 -0.442333  1.496646  0.085614
# 2000-01-03  0.833276 -0.293737  0.033843 -0.591689
# 2000-01-04  0.381749 -0.147020  1.377832  1.591534
# 2000-01-05 -0.426778  1.071627 -0.145696 -0.036683
# 2000-01-06  1.055798 -2.112462 -0.455006  1.832173
# 2000-01-07 -0.217709  0.170315  0.569208  1.518870
# 2000-01-08 -0.654928  0.626149  0.292917  0.590023
# 2000-01-09 -0.042763  0.651350  0.390071 -1.387189
# 2000-01-10  0.396463 -1.299817 -0.422292 -1.628396
#                    A         B         C         D
# 2000-01-01  0.424351  1.592704  1.524568  0.444328
# 2000-01-02  0.636823  1.150370  3.021214  0.529942
# 2000-01-03  1.470099  0.856633  3.055057 -0.061747
# 2000-01-04  1.427498 -0.883091  2.908321  1.085458
# 2000-01-05  0.788247  0.630870  1.265979  0.963162
# 2000-01-06  1.010769 -1.187855  0.777129  3.387024
# 2000-01-07  0.411310 -0.870520 -0.031495  3.314360
# 2000-01-08  0.183161 -1.315998  0.407118  3.941066
# 2000-01-09 -0.915400  1.447814  1.252195  0.721704
# 2000-01-10 -0.301227 -0.022317  0.260696 -2.425562

# %%
df = pd.DataFrame(np.random.randn(10, 4),
   index = pd.date_range('1/1/2000', periods=10),
   columns = ['A', 'B', 'C', 'D'])
print(df)
r = df.rolling(window=3,min_periods=1)
print (r['A'].aggregate(np.sum))
# Out:
#                    A         B         C         D
# 2000-01-01  0.446643 -0.116708  1.573003 -1.553732
# 2000-01-02 -0.258324 -0.941858  0.500301  1.566773
# 2000-01-03  0.750579 -0.128081  0.073401  0.144352
# 2000-01-04 -1.706593  0.479102 -0.298303  0.121816
# 2000-01-05  1.065360 -1.074499 -0.573158 -1.109915
# 2000-01-06  1.510301  0.181426 -1.394981  0.450459
# 2000-01-07 -1.287057 -0.209803 -0.102665  0.919790
# 2000-01-08 -1.681324 -1.438560  0.295416  0.433060
# 2000-01-09  0.706136  0.069085 -0.242575 -0.076237
# 2000-01-10  1.705446 -0.951342 -0.272018  2.346997
# 2000-01-01    0.446643
# 2000-01-02    0.188319
# 2000-01-03    0.938898
# 2000-01-04   -1.214338
# 2000-01-05    0.109347
# 2000-01-06    0.869068
# 2000-01-07    1.288604
# 2000-01-08   -1.458080
# 2000-01-09   -2.262245
# 2000-01-10    0.730258
# Freq: D, Name: A, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(10, 4),
   index = pd.date_range('1/1/2000', periods=10),
   columns = ['A', 'B', 'C', 'D'])
print df
r = df.rolling(window=3,min_periods=1)
print r[['A','B']].aggregate(np.sum)
